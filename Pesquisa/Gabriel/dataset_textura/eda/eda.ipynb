# %%
import matplotlib.pyplot as plt
import pandas as pd
import sys
import os

sys.path.append("../src")
from measurer import teste as tst
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 9
#       6 sys.path.append("../src")
#       7 from measurer import teste as tst
# ----> 9 teste_class = tst.Teste()
#      10 teste_class
#
# AttributeError: module 'measurer.teste' has no attribute 'Teste'

# %%
front = 'sample_data/front_render.png'
side = 'sample_data/back_render.png'

fig,ax = plt.subplots(1,2)
ax[0].imshow(plt.imread(front))
ax[1].imshow(plt.imread(side))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 6
#       4 fig,ax = plt.subplots(1,2)
#       5 ax[0].imshow(plt.imread(front))
# ----> 6 ax[1].imshow(plt.imread(side))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2123, in imread(fname, format)
#    2121 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2122 def imread(fname, format=None):
# -> 2123     return matplotlib.image.imread(fname, format)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:1541, in imread(fname, format)
#    1534 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1535     # Pillow doesn't handle URLs directly.
#    1536     raise ValueError(
#    1537         "Please open the URL for reading and pass the "
#    1538         "result to Pillow, e.g. with "
# ...
